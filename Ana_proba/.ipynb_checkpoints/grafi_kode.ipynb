# %%
# Preveri, da res teče Sage kernel in da so na voljo Sage grafi
import sys
print(sys.version)

G = graphs.KneserGraph(5, 2)
print(type(G))  # pričakovano: <class 'sage.graphs.graph.Graph'>
print(G.complement().clique_number())  # pričakovano: 4
# Out:
# 3.12.12 | packaged by conda-forge | (main, Oct 22 2025, 23:25:55) [GCC 14.3.0]
# <class 'sage.graphs.graph.Graph'>
# 4

# %%
###############################################################
# Celovita in optimizirana skripta za pregled Kneserjevih grafov
# - izračun alpha parametrov
# - zapis rezultatov v CSV
# - izris grafov, kjer veljajo želene enačbe
# Pripravljeno za SageMath kernel (CoCalc/Jupyter)
###############################################################

from itertools import combinations
from collections import deque
from sage.graphs.graph import Graph
from sage.all import oo   # +∞ (lahko tudi brez uvoza, v Sage jedru je globalno)
import os, csv, math, time

# ------------------ Optimizirane pomožne funkcije ------------------

def bfs_distances_from_source(G, source, idx):
    """
    BFS od 'source' vrne slovar razdalj do dosegljivih vozlišč.
    Nedosegljiva vozlišča bomo pozneje označili z oo.
    """
    dist = {source: 0}
    q = deque([source])
    seen = {source}
    while q:
        u = q.popleft()
        for v in G.neighbors(u):
            if v not in seen:
                seen.add(v)
                dist[v] = dist[u] + 1
                q.append(v)
    return dist

def all_pairs_distances(G):
    """
    Vrne (V, D) za poljubno (tudi nepovezan) graf:
    - V: seznam vozlišč v ustaljenem vrstnem redu
    - D: 2D seznam velikosti len(V) x len(V), z razdaljami (int) ali oo.
         Uporaba: D[i][j], ne D[i, j].
    """
    V = list(G.vertices())
    n = len(V)
    idx = {v: i for i, v in enumerate(V)}
    # inicializacija z oo
    D = [[oo for _ in range(n)] for _ in range(n)]
    for i in range(n):
        D[i][i] = 0

    # BFS za vsako izhodišče
    for i, u in enumerate(V):
        dist_u = bfs_distances_from_source(G, u, idx)
        for v, d in dist_u.items():
            j = idx[v]
            D[i][j] = d
    return V, D

def G_odd_from_distances(V, D):
    """
    Zgradi graf G_odd na množici V, z uporabo matrike razdalj D (2D seznam).
    Povezava med u,v obstaja <=> d(u,v) je liha.
    """
    Godd = Graph(multiedges=False, loops=False)
    Godd.add_vertices(V)
    nV = len(V)
    for i, j in combinations(range(nV), 2):
        dij = D[i][j]
        if dij != oo and dij % 2 == 1:
            Godd.add_edge(V[i], V[j])
    return Godd

def G_square_from_distances(V, D):
    """
    Zgradi graf G^2 na množici V, z uporabo matrike razdalj D (2D seznam).
    Povezava med u,v obstaja <=> d(u,v) <= 2.
    """
    G2 = Graph(multiedges=False, loops=False)
    G2.add_vertices(V)
    nV = len(V)
    for i, j in combinations(range(nV), 2):
        dij = D[i][j]
        if dij != oo and dij <= 2:
            G2.add_edge(V[i], V[j])
    return G2

def alpha_via_complement(G):
    """
    Izračun α(G) prek ekvivalence: α(G) = ω(komplement(G)).
    (Ker independence_number() ni na voljo, uporabimo clique_number() na komplementu.)
    """
    return G.complement().clique_number()

def alpha_params_fast(G):
    """
    Optimiziran izračun:
    - enkrat izračunamo matriko razdalj (BFS, deluje tudi za nepovezane grafe)
    - zgradimo G_odd in G^2 iz D
    - vrnemo (alpha, alpha_odd, alpha_square)
    """
    alpha = alpha_via_complement(G)
    V, D = all_pairs_distances(G)
    G_odd = G_odd_from_distances(V, D)
    G_sq  = G_square_from_distances(V, D)
    alpha_od = alpha_via_complement(G_odd)
    alpha_sq = alpha_via_complement(G_sq)
    return alpha, alpha_od, alpha_sq

# ------------------ Glavna rutina skeniranja ------------------

def scan_kneser_family(
    n_min=5, n_max=12,
    MAX_V_FOR_CSV=800,            # zgornja meja |V| za izračune in zapis v CSV
    MAX_V_FOR_PLOT=120,           # zgornja meja |V| za izris in shranjevanje slik
    plot_layout='spring',         # 'spring', 'circular', 'spectral', ...
    csv_path='kneser_alpha_scan.csv',
    dir_alpha_eq_alpha_odd='plots_alpha_eq_alpha_odd',
    dir_alpha_sq_eq_alpha='plots_alpha_sq_eq_alpha',
    PRINT_PROGRESS=True           # izpis napredka in časov
):
    """
    Pregleda KG(n,k) za n v [n_min, n_max] in k v [1, floor(n/2)].
    Filtrira po |V| = C(n,k) (kombinacijsko vnaprej) za CSV in za plot.
    Zapiše CSV in shrani slike grafov v ločene mape glede na veljavnost enačb:

      - α(G) = α(G_odd)
      - α(G^2) = α(G)

    CSV stolpci:
      n,k,num_vertices,alpha,alpha_odd,alpha_square,alpha_eq_alpha_odd,alpha_square_eq_alpha,seconds

    Opomba: izris (plot) se izvede le, če |V| <= MAX_V_FOR_PLOT.
    """
    # priprava map za slike
    os.makedirs(dir_alpha_eq_alpha_odd, exist_ok=True)
    os.makedirs(dir_alpha_sq_eq_alpha, exist_ok=True)

    total_started = time.time()

    with open(csv_path, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow([
            'n','k','num_vertices','alpha','alpha_odd','alpha_square',
            'alpha_eq_alpha_odd','alpha_square_eq_alpha','seconds'
        ])

        for n in range(n_min, n_max + 1):
            for k in range(1, n // 2 + 1):
                # ocena velikosti grafa vnaprej (|V| = C(n,k))
                V_count = math.comb(n, k)

                # če je preveliko za CSV, preskoči (da se ne zabaše časovno)
                if V_count > MAX_V_FOR_CSV:
                    if PRINT_PROGRESS:
                        print(f"Preskočeno KG({n},{k}) zaradi |V|={V_count} > {MAX_V_FOR_CSV}")
                    continue

                # konstrukt KG(n,k)
                t0 = time.time()
                G = graphs.KneserGraph(n, k)

                # robusten izračun alpha parametrov
                alpha, alpha_od, alpha_sq = alpha_params_fast(G)

                # indikatorji enačb
                eq1 = (alpha == alpha_od)
                eq2 = (alpha_sq == alpha)

                # zapis v CSV
                seconds = round(time.time() - t0, 3)
                writer.writerow([
                    n, k, V_count, alpha, alpha_od, alpha_sq, int(eq1), int(eq2), seconds
                ])

                # izpis napredka
                if PRINT_PROGRESS:
                    print(f"KG({n},{k}) |V|={V_count}: α={alpha}, α_odd={alpha_od}, α(G^2)={alpha_sq} "
                          f"| eq1={eq1}, eq2={eq2} | {seconds}s")

                # izris (le, če ni preveliko)
                if V_count <= MAX_V_FOR_PLOT:
                    base_name = f"KG_{n}_{k}_V{V_count}_a{alpha}_aod{alpha_od}_asq{alpha_sq}.png"
                    if eq1:
                        path1 = os.path.join(dir_alpha_eq_alpha_odd, base_name)
                        G.plot(layout=plot_layout).save(path1)
                    if eq2:
                        path2 = os.path.join(dir_alpha_sq_eq_alpha, base_name)
                        G.plot(layout=plot_layout).save(path2)

    print(f"✅ CSV zapisano v: {csv_path}")
    print(f"📁 Slike (α = α_odd) v: {dir_alpha_eq_alpha_odd}")
    print(f"📁 Slike (α(G²) = α) v: {dir_alpha_sq_eq_alpha}")
    print(f"⏱️ Skupen čas: {round(time.time() - total_started, 3)}s")

# ------------------ Primer zagona (prilagodi po potrebi) ------------------

# Zmerne privzete meje (dobro za začetek v CoCalc):
scan_kneser_family(
    n_min=5, n_max=12,
    MAX_V_FOR_CSV=800,         # dvigni na 1000, če gre hitro
    MAX_V_FOR_PLOT=120,        # za lep izris; več je nečitljivo in počasno
    plot_layout='spring',      # lahko tudi: 'circular' za lepšo simetrijo pri manjših grafih
    csv_path='kneser_alpha_scan.csv',
    PRINT_PROGRESS=True
)
# Out:
# KG(5,1) |V|=5: α=1, α_odd=1, α(G^2)=1 | eq1=True, eq2=True | 0.023s
# KG(5,2) |V|=10: α=4, α_odd=4, α(G^2)=1 | eq1=True, eq2=False | 0.007s
# KG(6,1) |V|=6: α=1, α_odd=1, α(G^2)=1 | eq1=True, eq2=True | 0.005s
# KG(6,2) |V|=15: α=5, α_odd=5, α(G^2)=1 | eq1=True, eq2=False | 0.022s
# KG(6,3) |V|=20: α=10, α_odd=10, α(G^2)=10 | eq1=True, eq2=True | 0.007s
# KG(7,1) |V|=7: α=1, α_odd=1, α(G^2)=1 | eq1=True, eq2=True | 0.003s
# KG(7,2) |V|=21: α=6, α_odd=6, α(G^2)=1 | eq1=True, eq2=False | 0.019s
# KG(7,3) |V|=35: α=15, α_odd=5, α(G^2)=7 | eq1=False, eq2=False | 0.038s
# KG(8,1) |V|=8: α=1, α_odd=1, α(G^2)=1 | eq1=True, eq2=True | 0.004s
# KG(8,2) |V|=28: α=7, α_odd=7, α(G^2)=1 | eq1=True, eq2=False | 0.041s
# KG(8,3) |V|=56: α=21, α_odd=21, α(G^2)=1 | eq1=True, eq2=False | 0.107s
# KG(8,4) |V|=70: α=35, α_odd=35, α(G^2)=35 | eq1=True, eq2=True | 0.022s
# KG(9,1) |V|=9: α=1, α_odd=1, α(G^2)=1 | eq1=True, eq2=True | 0.004s
# KG(9,2) |V|=36: α=8, α_odd=8, α(G^2)=1 | eq1=True, eq2=False | 0.052s
# KG(9,3) |V|=84: α=28, α_odd=28, α(G^2)=1 | eq1=True, eq2=False | 0.239s
# KG(9,4) |V|=126: α=56, α_odd=21, α(G^2)=12 | eq1=False, eq2=False | 3.819s
# KG(10,1) |V|=10: α=1, α_odd=1, α(G^2)=1 | eq1=True, eq2=True | 0.017s
# KG(10,2) |V|=45: α=9, α_odd=9, α(G^2)=1 | eq1=True, eq2=False | 0.173s
# KG(10,3) |V|=120: α=36, α_odd=36, α(G^2)=1 | eq1=True, eq2=False | 1.04s
# KG(10,4) |V|=210: α=84, α_odd=28, α(G^2)=5 | eq1=False, eq2=False | 1.654s
# KG(10,5) |V|=252: α=126, α_odd=126, α(G^2)=126 | eq1=True, eq2=True | 0.604s
# KG(11,1) |V|=11: α=1, α_odd=1, α(G^2)=1 | eq1=True, eq2=True | 0.016s
# KG(11,2) |V|=55: α=10, α_odd=10, α(G^2)=1 | eq1=True, eq2=False | 0.318s
# KG(11,3) |V|=165: α=45, α_odd=45, α(G^2)=1 | eq1=True, eq2=False | 1.79s
# KG(11,4) |V|=330: α=120, α_odd=120, α(G^2)=1 | eq1=True, eq2=False | 16.878s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 196
#     191     print(f"⏱️ Skupen čas: {round(time.time() - total_started, Integer(3))}s")
#     193 # ------------------ Primer zagona (prilagodi po potrebi) ------------------
#     194
#     195 # Zmerne privzete meje (dobro za začetek v CoCalc):
# --> 196 scan_kneser_family(
#     197     n_min=Integer(5), n_max=Integer(12),
#     198     MAX_V_FOR_CSV=Integer(800),         # dvigni na 1000, če gre hitro
#     199     MAX_V_FOR_PLOT=Integer(120),        # za lep izris; več je nečitljivo in počasno
#     200     plot_layout='spring',      # lahko tudi: 'circular' za lepšo simetrijo pri manjših grafih
#     201     csv_path='kneser_alpha_scan.csv',
#     202     PRINT_PROGRESS=True
#     203 )
#
# Cell In[2], line 161, in scan_kneser_family(n_min, n_max, MAX_V_FOR_CSV, MAX_V_FOR_PLOT, plot_layout, csv_path, dir_alpha_eq_alpha_odd, dir_alpha_sq_eq_alpha, PRINT_PROGRESS)
#     158 G = graphs.KneserGraph(n, k)
#     160 # robusten izračun alpha parametrov
# --> 161 alpha, alpha_od, alpha_sq = alpha_params_fast(G)
#     163 # indikatorji enačb
#     164 eq1 = (alpha == alpha_od)
#
# Cell In[2], line 99, in alpha_params_fast(G)
#      92 def alpha_params_fast(G):
#      93     """
#      94     Optimiziran izračun:
#      95     - enkrat izračunamo matriko razdalj (BFS, deluje tudi za nepovezane grafe)
#      96     - zgradimo G_odd in G^2 iz D
#      97     - vrnemo (alpha, alpha_odd, alpha_square)
#      98     """
# ---> 99     alpha = alpha_via_complement(G)
#     100     V, D = all_pairs_distances(G)
#     101     G_odd = G_odd_from_distances(V, D)
#
# Cell In[2], line 90, in alpha_via_complement(G)
#      85 def alpha_via_complement(G):
#      86     """
#      87     Izračun α(G) prek ekvivalence: α(G) = ω(komplement(G)).
#      88     (Ker independence_number() ni na voljo, uporabimo clique_number() na komplementu.)
#      89     """
# ---> 90     return G.complement().clique_number()
#
# File ~/miniconda3/envs/sagemath/lib/python3.12/site-packages/sage/graphs/graph.py:6268, in Graph.clique_number(self, algorithm, cliques, solver, verbose, integrality_tolerance)
#    6266 if algorithm == "Cliquer":
#    6267     from sage.graphs.cliquer import clique_number
# -> 6268     return clique_number(self)
#    6269 elif algorithm == "networkx":
#    6270     import networkx
#
# File ~/miniconda3/envs/sagemath/lib/python3.12/site-packages/sage/graphs/cliquer.pyx:326, in sage.graphs.cliquer.clique_number (build/cythonized/sage/graphs/cliquer.c:6580)()
#     324
#     325     cdef int c
# --> 326     sig_on()
#     327     c = sage_clique_number(g)
#     328     graph_free(g)
#
# KeyboardInterrupt:

# %%
###############################################################
# KG(n,k): preverjanje enakosti
#   (1) alpha_odd == alpha
#   (2) alpha_odd == alpha(G^2)
# Organizirano shranjevanje v: rezultati/<RUN_TAG>/
# - α(KG(n,k)) po Erdos–Ko–Rado (zaprt obrazec)
# - razdalje prek BFS (deluje tudi za nepovezane grafe)
# - robusten CSV zapis (append & close), absolutna pot + velikost
# - izris primerov + montaže (mozaiki) slik
###############################################################

from itertools import combinations
from collections import deque
from sage.graphs.graph import Graph
from sage.all import oo
import os, csv, math, time
from datetime import datetime

# ---------- Nastavitev teka in map ----------
RUN_TAG = "drugic"  # npr. "drugic" ali časovni žig
# RUN_TAG = datetime.now().strftime("%Y%m%d_%H%M%S")

BASE_DIR  = os.path.join("rezultati", RUN_TAG)
CSV_NAME  = f"kneser_alpha_scan_{RUN_TAG}.csv"
CSV_PATH  = os.path.join(BASE_DIR, CSV_NAME)
DIR_EQ1   = os.path.join(BASE_DIR, "plots_alpha_od_eq_alpha")       # α_odd == α
DIR_EQ2   = os.path.join(BASE_DIR, "plots_alpha_od_eq_alpha_sq")    # α_odd == α(G^2)
MONTAGE_EQ1 = os.path.join(BASE_DIR, f"montage_alpha_od_eq_alpha_{RUN_TAG}.png")
MONTAGE_EQ2 = os.path.join(BASE_DIR, f"montage_alpha_od_eq_alpha_sq_{RUN_TAG}.png")

os.makedirs(DIR_EQ1, exist_ok=True)
os.makedirs(DIR_EQ2, exist_ok=True)

# ---------- α(KG(n,k)) po Erdos–Ko–Rado ----------
def kneser_alpha_closed_form(n, k):
    """
    α(KG(n,k)):
      - če n < 2k: graf je prazen, α = C(n,k)
      - če n >= 2k: α = C(n-1, k-1)
    """
    if n < 2*k:
        return math.comb(n, k)
    else:
        return math.comb(n-1, k-1)

# ---------- BFS razdalje (deluje tudi za nepovezane grafe) ----------
def bfs_distances_from_source(G, source):
    dist = {source: 0}
    q = deque([source])
    seen = {source}
    while q:
        u = q.popleft()
        for v in G.neighbors(u):
            if v not in seen:
                seen.add(v)
                dist[v] = dist[u] + 1
                q.append(v)
    return dist

def all_pairs_distances(G):
    V = list(G.vertices())
    n = len(V)
    idx = {v: i for i, v in enumerate(V)}
    D = [[oo for _ in range(n)] for _ in range(n)]
    for i in range(n):
        D[i][i] = 0
    for i, u in enumerate(V):
        dist_u = bfs_distances_from_source(G, u)
        for v, d in dist_u.items():
            j = idx[v]
            D[i][j] = d
    return V, D

# ---------- G_odd in G^2 ----------
def G_odd_from_distances(V, D):
    Godd = Graph(multiedges=False, loops=False)
    Godd.add_vertices(V)
    nV = len(V)
    for i, j in combinations(range(nV), 2):
        d = D[i][j]
        if d != oo and d % 2 == 1:
            Godd.add_edge(V[i], V[j])
    return Godd

def G_square_from_distances(V, D):
    G2 = Graph(multiedges=False, loops=False)
    G2.add_vertices(V)
    nV = len(V)
    for i, j in combinations(range(nV), 2):
        d = D[i][j]
        if d != oo and d <= 2:
            G2.add_edge(V[i], V[j])
    return G2

# ---------- α(G) prek klike v komplementu ----------
def alpha_via_complement(G):
    return G.complement().clique_number()

# ---------- Parametri za KG(n,k) ----------
def alpha_params_for_kneser(n, k):
    """
    Vrne (G, alpha, alpha_odd, alpha_square) za KG(n,k).
      - α: zaprt obrazec (hiter)
      - α_odd, α_square: prek G_odd/G^2 + ω(komplement)
    """
    G = graphs.KneserGraph(n, k)
    alpha = kneser_alpha_closed_form(n, k)
    V, D = all_pairs_distances(G)
    G_odd = G_odd_from_distances(V, D)
    G_sq  = G_square_from_distances(V, D)
    alpha_od = alpha_via_complement(G_odd)
    alpha_sq = alpha_via_complement(G_sq)
    return G, alpha, alpha_od, alpha_sq

# ---------- CSV helperji (append & close) ----------
def ensure_csv_with_header(csv_path):
    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    if not os.path.exists(csv_path) or os.path.getsize(csv_path) == 0:
        with open(csv_path, 'w', newline='', encoding='utf-8') as f:
            w = csv.writer(f)
            w.writerow([
                'run_tag','n','k','num_vertices','alpha','alpha_odd','alpha_square',
                'alpha_odd_eq_alpha','alpha_odd_eq_alpha_square','seconds'
            ])

def append_row(csv_path, row):
    with open(csv_path, 'a', newline='', encoding='utf-8') as f:
        w = csv.writer(f)
        w.writerow(row)

# ---------- Glavna rutina skeniranja ----------
def scan_kneser_family(
    n_min=1, n_max=10,
    MAX_V_FOR_CSV=600,
    MAX_V_FOR_PLOT=100,
    plot_layout='circular',
    PRINT_PROGRESS=True,
    time_limit_seconds=None,   # npr. 20*60
    max_cases=None             # npr. 30
):
    start_time = time.time()
    cases_done = 0

    csv_abs = os.path.abspath(CSV_PATH)
    print(f"📄 CSV bo shranjen v: {csv_abs}")
    print(f"📂 cwd: {os.getcwd()}")
    print(f"🗂️ Rezultati v: {os.path.abspath(BASE_DIR)}")

    ensure_csv_with_header(CSV_PATH)

    for n in range(n_min, n_max + 1):
        for k in range(1, n // 2 + 1):

            # kontrola časa/števil primerov
            if time_limit_seconds is not None and (time.time() - start_time) > time_limit_seconds:
                print(f"⏹️ Ustavljeno zaradi time_limit ({time_limit_seconds}s). Do sem: {cases_done} primerov.")
                return
            if max_cases is not None and cases_done >= max_cases:
                print(f"⏹️ Ustavljeno zaradi max_cases={max_cases}.")
                return

            V_count = math.comb(n, k)
            if V_count > MAX_V_FOR_CSV:
                if PRINT_PROGRESS:
                    print(f"⏭️ Preskočeno KG({n},{k}) |V|={V_count} > {MAX_V_FOR_CSV}")
                continue

            t0 = time.time()
            G, alpha, alpha_od, alpha_sq = alpha_params_for_kneser(n, k)
            eq1 = (alpha_od == alpha)     # α_odd = α
            eq2 = (alpha_od == alpha_sq)  # α_odd = α(G^2)
            seconds = round(time.time() - t0, 3)

            # zapis (append & close)
            append_row(CSV_PATH, [
                RUN_TAG, n, k, V_count, alpha, alpha_od, alpha_sq, int(eq1), int(eq2), seconds
            ])
            cases_done += 1

            if PRINT_PROGRESS:
                print(f"✅ KG({n},{k}) |V|={V_count}: α={alpha}, α_odd={alpha_od}, α(G^2)={alpha_sq} "
                      f"| eq1(α_odd=α)={eq1}, eq2(α_odd=α(G^2))={eq2} | {seconds}s")

            # izris (le, če ni preveliko)
            if V_count <= MAX_V_FOR_PLOT:
                base = f"KG_{n}_{k}_V{V_count}_a{alpha}_aodd{alpha_od}_asq{alpha_sq}_{RUN_TAG}.png"
                if eq1:
                    p1 = os.path.join(DIR_EQ1, base)
                    G.plot(layout=plot_layout).save(p1)
                if eq2:
                    p2 = os.path.join(DIR_EQ2, base)
                    G.plot(layout=plot_layout).save(p2)

    # po koncu
    if os.path.exists(csv_abs):
        size = os.path.getsize(csv_abs)
        print(f"📏 CSV velikost: {size} bytes | zapisane vrstice: {cases_done}")
    print("⏱️ Skupen čas:", round(time.time() - start_time, 3), "s")

# ---------- Montaža (mozaik) ----------
def create_montage_from_dir(
    dir_path,
    output_path,
    thumb_size=(300, 300),
    cols=4,
    pad=10,
    add_labels=True,
    max_images=None
):
    try:
        from PIL import Image, ImageDraw, ImageFont
    except ImportError:
        print("⚠️ PIL (Pillow) ni nameščen v Sage okolju. Montaža se preskoči.")
        return

    files = sorted([f for f in os.listdir(dir_path) if f.lower().endswith('.png')])
    if max_images is not None:
        files = files[:max_images]
    if not files:
        print(f"⚠️ Ni slik v: {dir_path}, preskočim montažo.")
        return

    W, H = thumb_size
    rows = (len(files) + cols - 1) // cols
    canvas_w = cols * W + (cols + 1) * pad
    canvas_h = rows * H + (rows + 1) * pad

    canvas = Image.new('RGB', (canvas_w, canvas_h), color=(255, 255, 255))
    draw = ImageDraw.Draw(canvas)
    try:
        font = ImageFont.load_default()
    except Exception:
        font = None

    def parse_label_from_filename(fn):
        base = os.path.splitext(fn)[0]
        try:
            parts = base.split('_')
            # primer: ['KG','n','k','V{V}','a{alpha}','aodd{alpha_od}','asq{alpha_sq}','{RUN_TAG}']
            n = parts[1]
            k = parts[2]
            V = parts[3][1:]   # 'V...'
            a  = parts[4][1:]  # 'a...'
            aod = parts[5][4:] # 'aodd...'
            asq = parts[6][3:] # 'asq...'
            return f"n={n}, k={k}, V={V}\nα={a}, α_odd={aod}, α(G²)={asq}"
        except Exception:
            return base

    for idx, fn in enumerate(files):
        img = Image.open(os.path.join(dir_path, fn)).convert('RGB')
        img = img.resize(thumb_size, Image.LANCZOS)
        r = idx // cols
        c = idx % cols
        x = pad + c * (W + pad)
        y = pad + r * (H + pad)
        canvas.paste(img, (x, y))
        if add_labels:
            draw.text((x + 5, y + 5), parse_label_from_filename(fn), fill=(0,0,0), font=font)

    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    canvas.save(output_path)
    print(f"🖼️ Montaža shranjena: {os.path.abspath(output_path)}")

# ---------- Zagon ----------
scan_kneser_family(
    n_min=5, n_max=10,          # dvigni na 11 ali 12, ko vidiš čase
    MAX_V_FOR_CSV=600,          # dvigni na 800 ali 1000 po potrebi
    MAX_V_FOR_PLOT=100,
    plot_layout='circular',
    PRINT_PROGRESS=True,
    time_limit_seconds=20*60,   # npr. ustavi po 20 minutah (ali None)
    max_cases=None              # npr. 30 (ali None)
)

create_montage_from_dir(
    dir_path=DIR_EQ1,
    output_path=MONTAGE_EQ1,
    thumb_size=(320, 320),
    cols=4,
    pad=12,
    add_labels=True
)

create_montage_from_dir(
    dir_path=DIR_EQ2,
    output_path=MONTAGE_EQ2,
    thumb_size=(320, 320),
    cols=4,
    pad=12,
    add_labels=True
)

# --- Hitra kontrola CSV ---
print("CSV pot:", os.path.abspath(CSV_PATH))
print("CSV obstaja?", os.path.exists(CSV_PATH))
print("CSV velikost (bytes):", os.path.getsize(CSV_PATH) if os.path.exists(CSV_PATH) else "NA")
# Out:
# 📄 CSV bo shranjen v: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints/rezultati/drugic/kneser_alpha_scan_drugic.csv
# 📂 cwd: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints
# 🗂️ Rezultati v: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints/rezultati/drugic
# ✅ KG(5,1) |V|=5: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.101s
# ✅ KG(5,2) |V|=10: α=4, α_odd=4, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.014s
# ✅ KG(6,1) |V|=6: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.005s
# ✅ KG(6,2) |V|=15: α=5, α_odd=5, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.017s
# ✅ KG(6,3) |V|=20: α=10, α_odd=10, α(G^2)=10 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.016s
# ✅ KG(7,1) |V|=7: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.017s
# ✅ KG(7,2) |V|=21: α=6, α_odd=6, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.042s
# ✅ KG(7,3) |V|=35: α=15, α_odd=5, α(G^2)=7 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 0.055s
# ✅ KG(8,1) |V|=8: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.003s
# ✅ KG(8,2) |V|=28: α=7, α_odd=7, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.036s
# ✅ KG(8,3) |V|=56: α=21, α_odd=21, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.07s
# ✅ KG(8,4) |V|=70: α=35, α_odd=35, α(G^2)=35 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.022s
# ✅ KG(9,1) |V|=9: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.004s
# ✅ KG(9,2) |V|=36: α=8, α_odd=8, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.053s
# ✅ KG(9,3) |V|=84: α=28, α_odd=28, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.241s
# ✅ KG(9,4) |V|=126: α=56, α_odd=21, α(G^2)=12 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 3.021s
# ✅ KG(10,1) |V|=10: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.005s
# ✅ KG(10,2) |V|=45: α=9, α_odd=9, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.089s
# ✅ KG(10,3) |V|=120: α=36, α_odd=36, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.602s
# ✅ KG(10,4) |V|=210: α=84, α_odd=28, α(G^2)=5 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 0.996s
# ✅ KG(10,5) |V|=252: α=126, α_odd=126, α(G^2)=126 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.21s
# 📏 CSV velikost: 785 bytes | zapisane vrstice: 21
# ⏱️ Skupen čas: 11.585 s
# 🖼️ Montaža shranjena: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints/rezultati/drugic/montage_alpha_od_eq_alpha_drugic.png
# 🖼️ Montaža shranjena: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints/rezultati/drugic/montage_alpha_od_eq_alpha_sq_drugic.png
# CSV pot: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints/rezultati/drugic/kneser_alpha_scan_drugic.csv
# CSV obstaja? True
# CSV velikost (bytes): 785

# %%
# ============================================
# KNESER: skeniranje + montaža (celoten skript)
# ============================================

import os
import csv
import math
import time

# -------------------------------------------------------
# Konstante in poti (po potrebi prilagodi)
# -------------------------------------------------------
BASE_DIR = os.path.abspath(os.path.join(".", "results"))
os.makedirs(BASE_DIR, exist_ok=True)

# RUN_TAG naj ostane kot ga imaš (če ga že nastavljaš drugje), sicer:
RUN_TAG = time.strftime("run_%Y%m%d-%H%M%S")

CSV_PATH    = os.path.join(BASE_DIR, f"kneser_scan_{RUN_TAG}.csv")
DIR_EQ1     = os.path.join(BASE_DIR, "eq_alphaodd_eq_alpha")
DIR_EQ2     = os.path.join(BASE_DIR, "eq_alphaodd_eq_alphasq")
MONTAGE_EQ1 = os.path.join(BASE_DIR, f"montage_eq1_{RUN_TAG}.png")
MONTAGE_EQ2 = os.path.join(BASE_DIR, f"montage_eq2_{RUN_TAG}.png")

# -------------------------------------------------------
# Helperji za CSV (minimalno, da ti ne spremenim logike)
# -------------------------------------------------------
def ensure_csv_with_header(path):
    """
    Ustvari CSV z glavo, če še ne obstaja ali je prazen.
    Glava je točno v formatu, ki si ga želela.
    """
    header = [
        "run_tag", "n", "k", "V_count",
        "alpha", "alpha_odd", "alpha_sq",
        "eq1_alphaodd_eq_alpha",
        "eq2_alphaodd_eq_alphasq",
        "seconds"
    ]
    os.makedirs(os.path.dirname(path), exist_ok=True)
    if not os.path.exists(path) or os.path.getsize(path) == 0:
        with open(path, "w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(header)

def append_row(path, row):
    """Doda eno vrstico v CSV (append & close)."""
    with open(path, "a", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(row)

# -------------------------------------------------------
# Pričakovana funkcija:
# alpha_params_for_kneser(n, k) -> (G, alpha, alpha_odd, alpha_sq)
# - G : Sage graf K(n,k)
# - alpha : α(G)
# - alpha_odd : α_odd(G) = α(G_odd)
# - alpha_sq : α(G^2)
# -------------------------------------------------------
# Če jo imaš v drugem modulu, tu naredi:
# from tvoj_modul import alpha_params_for_kneser


# ---------- Glavna rutina skeniranja ----------
def scan_kneser_family(
    n_min=1, n_max=11,          # ✅ 1..11 po zahtevi
    MAX_V_FOR_CSV=600,
    MAX_V_FOR_PLOT=100,
    plot_layout='circular',
    PRINT_PROGRESS=True,
    time_limit_seconds=None,   # npr. 20*60
    max_cases=None             # npr. 30
):
    start_time = time.time()
    cases_done = 0

    csv_abs = os.path.abspath(CSV_PATH)
    print(f"📄 CSV bo shranjen v: {csv_abs}")
    print(f"📂 cwd: {os.getcwd()}")
    print(f"🗂️ Rezultati v: {os.path.abspath(BASE_DIR)}")

    ensure_csv_with_header(CSV_PATH)

    # poskrbi, da mapi za slike obstajata
    os.makedirs(DIR_EQ1, exist_ok=True)
    os.makedirs(DIR_EQ2, exist_ok=True)

    for n in range(n_min, n_max + 1):
        for k in range(1, n // 2 + 1):

            # kontrola časa/števil primerov
            if time_limit_seconds is not None and (time.time() - start_time) > time_limit_seconds:
                print(f"⏹️ Ustavljeno zaradi time_limit ({time_limit_seconds}s). Do sem: {cases_done} primerov.")
                return
            if max_cases is not None and cases_done >= max_cases:
                print(f"⏹️ Ustavljeno zaradi max_cases={max_cases}.")
                return

            V_count = math.comb(n, k)

            # NE preskakujemo zapisov v CSV — samo informativno sporočilo
            if V_count > MAX_V_FOR_CSV and PRINT_PROGRESS:
                print(f"ℹ️ KG({n},{k}) |V|={V_count} > MAX_V_FOR_CSV={MAX_V_FOR_CSV}, "
                      f"a zapis v CSV bo vseeno narejen (po zahtevi).")

            t0 = time.time()
            G, alpha, alpha_od, alpha_sq = alpha_params_for_kneser(n, k)
            eq1 = (alpha_od == alpha)     # α_odd = α
            eq2 = (alpha_od == alpha_sq)  # α_odd = α(G^2)
            seconds = round(time.time() - t0, 3)

            # zapis v CSV: vedno, za vse grafe, z vsemi polji
            append_row(CSV_PATH, [
                RUN_TAG, n, k, V_count, alpha, alpha_od, alpha_sq, bool(eq1), bool(eq2), seconds
            ])
            cases_done += 1

            if PRINT_PROGRESS:
                print(f"✅ KG({n},{k}) |V|={V_count}: α={alpha}, α_odd={alpha_od}, α(G^2)={alpha_sq} "
                      f"| eq1(α_odd=α)={eq1}, eq2(α_odd=α(G^2))={eq2} | {seconds}s")

            # ---------- izris ----------
            # Če enakost drži -> vedno naredimo sliko (brez omejitve MAX_V_FOR_PLOT).
            # Če enakost ne drži -> slika le, če je |V| <= MAX_V_FOR_PLOT (tvoja izvorna logika).
            base = f"KG_{n}_{k}_V{V_count}_a{alpha}_aodd{alpha_od}_asq{alpha_sq}_{RUN_TAG}.png"

            if eq1 or (V_count <= MAX_V_FOR_PLOT):
                p1 = os.path.join(DIR_EQ1, base)
                try:
                    G.plot(layout=plot_layout).save(p1)
                except Exception as e:
                    print(f"⚠️ Napaka pri shranjevanju slike (eq1) za KG({n},{k}): {e}")

            if eq2 or (V_count <= MAX_V_FOR_PLOT):
                p2 = os.path.join(DIR_EQ2, base)
                try:
                    G.plot(layout=plot_layout).save(p2)
                except Exception as e:
                    print(f"⚠️ Napaka pri shranjevanju slike (eq2) za KG({n},{k}): {e}")

    # po koncu
    if os.path.exists(csv_abs):
        size = os.path.getsize(csv_abs)
        print(f"📏 CSV velikost: {size} bytes | zapisane vrstice: {cases_done}")
    print("⏱️ Skupen čas:", round(time.time() - start_time, 3), "s")


# ---------- Montaža (mozaik) ----------
def create_montage_from_dir(
    dir_path,
    output_path,
    thumb_size=(300, 300),
    cols=4,
    pad=10,
    add_labels=True,
    max_images=None
):
    try:
        from PIL import Image, ImageDraw, ImageFont
    except ImportError:
        print("⚠️ PIL (Pillow) ni nameščen v Sage okolju. Montaža se preskoči.")
        return

    if not os.path.isdir(dir_path):
        print(f"⚠️ Mapa za montažo ne obstaja: {dir_path}")
        return

    files = sorted([f for f in os.listdir(dir_path) if f.lower().endswith('.png')])
    if max_images is not None:
        files = files[:max_images]
    if not files:
        print(f"⚠️ Ni slik v: {dir_path}, preskočim montažo.")
        return

    W, H = thumb_size
    rows = (len(files) + cols - 1) // cols
    canvas_w = cols * W + (cols + 1) * pad
    canvas_h = rows * H + (rows + 1) * pad

    from PIL import Image, ImageDraw, ImageFont
    canvas = Image.new('RGB', (canvas_w, canvas_h), color=(255, 255, 255))
    draw = ImageDraw.Draw(canvas)
    try:
        font = ImageFont.load_default()
    except Exception:
        font = None

    # robustnejši parser imena (da kolaži ne izpustijo slik)
    def parse_label_from_filename(fn):
        base = os.path.splitext(fn)[0]
        parts = base.split('_')
        vals = {"n": None, "k": None, "V": None, "a": None, "aodd": None, "asq": None}

        # prvi dve čisti številki kot n, k
        numeric = [p for p in parts if p.isdigit()]
        if len(numeric) >= 1:
            vals["n"] = numeric[0]
        if len(numeric) >= 2:
            vals["k"] = numeric[1]

        # prefiksi
        for p in parts:
            if p.startswith("V"):
                vals["V"] = p[1:]
            elif p.startswith("aodd"):
                vals["aodd"] = p[4:]
            elif p.startswith("asq"):
                vals["asq"] = p[3:]
            elif p.startswith("a") and not p.startswith("aodd") and not p.startswith("asq"):
                vals["a"] = p[1:]

        n = vals["n"] if vals["n"] is not None else "?"
        k = vals["k"] if vals["k"] is not None else "?"
        V = vals["V"] if vals["V"] is not None else "?"
        a = vals["a"] if vals["a"] is not None else "?"
        aod = vals["aodd"] if vals["aodd"] is not None else "?"
        asq = vals["asq"] if vals["asq"] is not None else "?"
        return f"n={n}, k={k}, V={V}\nα={a}, α_odd={aod}, α(G²)={asq}"

    for idx, fn in enumerate(files):
        full = os.path.join(dir_path, fn)
        try:
            img = Image.open(full).convert('RGB')
        except Exception as e:
            print(f"⚠️ Ne morem odpreti slike '{full}': {e}")
            continue

        img = img.resize(thumb_size, Image.LANCZOS)
        r = idx // cols
        c = idx % cols
        x = pad + c * (W + pad)
        y = pad + r * (H + pad)
        canvas.paste(img, (x, y))
        if add_labels and font is not None:
            draw.text((x + 5, y + 5), parse_label_from_filename(fn), fill=(0,0,0), font=font)

    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    canvas.save(output_path)
    print(f"🖼️ Montaža shranjena: {os.path.abspath(output_path)}")


# ---------- Zagon ----------
if __name__ == "__main__":
    scan_kneser_family(
        n_min=1, n_max=11,          # ✅ po zahtevi
        MAX_V_FOR_CSV=600,          # po potrebi lahko dvigneš
        MAX_V_FOR_PLOT=100,
        plot_layout='circular',
        PRINT_PROGRESS=True,
        time_limit_seconds=20*60,   # npr. ustavi po 20 minutah (ali None)
        max_cases=None              # npr. 30 (ali None)
    )

    create_montage_from_dir(
        dir_path=DIR_EQ1,
        output_path=MONTAGE_EQ1,
        thumb_size=(320, 320),
        cols=4,
        pad=12,
        add_labels=True
    )

    create_montage_from_dir(
        dir_path=DIR_EQ2,
        output_path=MONTAGE_EQ2,
        thumb_size=(320, 320),
        cols=4,
        pad=12,
        add_labels=True
    )

    # --- Hitra kontrola CSV ---
    print("CSV pot:", os.path.abspath(CSV_PATH))
    print("CSV obstaja?", os.path.exists(CSV_PATH))
    print("CSV velikost (bytes):", os.path.getsize(CSV_PATH) if os.path.exists(CSV_PATH) else "NA")
# Out:
# 📄 CSV bo shranjen v: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints/results/kneser_scan_run_20251208-131650.csv
# 📂 cwd: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints
# 🗂️ Rezultati v: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints/results
# ✅ KG(2,1) |V|=2: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.127s
# ✅ KG(3,1) |V|=3: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.034s
# ✅ KG(4,1) |V|=4: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.013s
# ✅ KG(4,2) |V|=6: α=3, α_odd=3, α(G^2)=3 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.018s
# ✅ KG(5,1) |V|=5: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.004s
# ✅ KG(5,2) |V|=10: α=4, α_odd=4, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.015s
# ✅ KG(6,1) |V|=6: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.004s
# ✅ KG(6,2) |V|=15: α=5, α_odd=5, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.05s
# ✅ KG(6,3) |V|=20: α=10, α_odd=10, α(G^2)=10 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.007s
# ✅ KG(7,1) |V|=7: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.006s
# ✅ KG(7,2) |V|=21: α=6, α_odd=6, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.016s
# ✅ KG(7,3) |V|=35: α=15, α_odd=5, α(G^2)=7 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 0.026s
# ✅ KG(8,1) |V|=8: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.005s
# ✅ KG(8,2) |V|=28: α=7, α_odd=7, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.031s
# ✅ KG(8,3) |V|=56: α=21, α_odd=21, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.078s
# ✅ KG(8,4) |V|=70: α=35, α_odd=35, α(G^2)=35 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.027s
# ✅ KG(9,1) |V|=9: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.005s
# ✅ KG(9,2) |V|=36: α=8, α_odd=8, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.055s
# ✅ KG(9,3) |V|=84: α=28, α_odd=28, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.229s
# ✅ KG(9,4) |V|=126: α=56, α_odd=21, α(G^2)=12 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 3.107s
# ✅ KG(10,1) |V|=10: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.006s
# ✅ KG(10,2) |V|=45: α=9, α_odd=9, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.099s
# ✅ KG(10,3) |V|=120: α=36, α_odd=36, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.695s
# ✅ KG(10,4) |V|=210: α=84, α_odd=28, α(G^2)=5 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 1.335s
# ✅ KG(10,5) |V|=252: α=126, α_odd=126, α(G^2)=126 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.319s
# ✅ KG(11,1) |V|=11: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.005s
# ✅ KG(11,2) |V|=55: α=10, α_odd=10, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.162s
# ✅ KG(11,3) |V|=165: α=45, α_odd=45, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 1.547s
# ✅ KG(11,4) |V|=330: α=120, α_odd=120, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 9.166s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 244
#     242 # ---------- Zagon ----------
#     243 if __name__ == "__main__":
# --> 244     scan_kneser_family(
#     245         n_min=Integer(1), n_max=Integer(11),          # ✅ po zahtevi
#     246         MAX_V_FOR_CSV=Integer(600),          # po potrebi lahko dvigneš
#     247         MAX_V_FOR_PLOT=Integer(100),
#     248         plot_layout='circular',
#     249         PRINT_PROGRESS=True,
#     250         time_limit_seconds=Integer(20)*Integer(60),   # npr. ustavi po 20 minutah (ali None)
#     251         max_cases=None              # npr. 30 (ali None)
#     252     )
#     254     create_montage_from_dir(
#     255         dir_path=DIR_EQ1,
#     256         output_path=MONTAGE_EQ1,
#    (...)
#     260         add_labels=True
#     261     )
#     263     create_montage_from_dir(
#     264         dir_path=DIR_EQ2,
#     265         output_path=MONTAGE_EQ2,
#    (...)
#     269         add_labels=True
#     270     )
#
# Cell In[5], line 107, in scan_kneser_family(n_min, n_max, MAX_V_FOR_CSV, MAX_V_FOR_PLOT, plot_layout, PRINT_PROGRESS, time_limit_seconds, max_cases)
#     103     print(f"ℹ️ KG({n},{k}) |V|={V_count} > MAX_V_FOR_CSV={MAX_V_FOR_CSV}, "
#     104           f"a zapis v CSV bo vseeno narejen (po zahtevi).")
#     106 t0 = time.time()
# --> 107 G, alpha, alpha_od, alpha_sq = alpha_params_for_kneser(n, k)
#     108 eq1 = (alpha_od == alpha)     # α_odd = α
#     109 eq2 = (alpha_od == alpha_sq)  # α_odd = α(G^2)
#
# Cell In[3], line 112, in alpha_params_for_kneser(n, k)
#     110 G_sq  = G_square_from_distances(V, D)
#     111 alpha_od = alpha_via_complement(G_odd)
# --> 112 alpha_sq = alpha_via_complement(G_sq)
#     113 return G, alpha, alpha_od, alpha_sq
#
# Cell In[3], line 97, in alpha_via_complement(G)
#      96 def alpha_via_complement(G):
# ---> 97     return G.complement().clique_number()
#
# File ~/miniconda3/envs/sagemath/lib/python3.12/site-packages/sage/graphs/graph.py:6268, in Graph.clique_number(self, algorithm, cliques, solver, verbose, integrality_tolerance)
#    6266 if algorithm == "Cliquer":
#    6267     from sage.graphs.cliquer import clique_number
# -> 6268     return clique_number(self)
#    6269 elif algorithm == "networkx":
#    6270     import networkx
#
# File ~/miniconda3/envs/sagemath/lib/python3.12/site-packages/sage/graphs/cliquer.pyx:326, in sage.graphs.cliquer.clique_number (build/cythonized/sage/graphs/cliquer.c:6580)()
#     324
#     325     cdef int c
# --> 326     sig_on()
#     327     c = sage_clique_number(g)
#     328     graph_free(g)
#
# KeyboardInterrupt:

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /home/naana/miniconda3/envs/sagemath/lib/python3.12/site-packages (11.3.0)

# %%
# ============================================
# KNESER: skeniranje + ILP α_odd + montaža
# ============================================

import os
import csv
import math
import time
from itertools import combinations

# --- Sage MIP (ILP/MILP) ---
from sage.numerical.mip import MixedIntegerLinearProgram, MIPSolverException

# -------------------------------------------------------
# Konstante in poti (po potrebi prilagodi)
# -------------------------------------------------------
BASE_DIR = os.path.abspath(os.path.join(".", "results3"))
os.makedirs(BASE_DIR, exist_ok=True)

RUN_TAG = time.strftime("run_%Y%m%d-%H%M%S")

CSV_PATH    = os.path.join(BASE_DIR, f"kneser_scan_{RUN_TAG}.csv")
DIR_EQ1     = os.path.join(BASE_DIR, "eq_alphaodd_eq_alpha")      # α_odd = α
DIR_EQ2     = os.path.join(BASE_DIR, "eq_alphaodd_eq_alphasq")    # α_odd = α(G^2)
MONTAGE_EQ1 = os.path.join(BASE_DIR, f"montage_eq1_{RUN_TAG}.png")
MONTAGE_EQ2 = os.path.join(BASE_DIR, f"montage_eq2_{RUN_TAG}.png")

# -------------------------------------------------------
# Helperji za CSV
# -------------------------------------------------------
def ensure_csv_with_header(path):
    """
    Ustvari CSV z glavo, če še ne obstaja ali je prazen.
    Glava je v formatu, ki si ga želela.
    """
    header = [
        "run_tag", "n", "k", "V_count",
        "alpha", "alpha_odd", "alpha_sq",
        "eq1_alphaodd_eq_alpha",
        "eq2_alphaodd_eq_alphasq",
        "seconds"
    ]
    os.makedirs(os.path.dirname(path), exist_ok=True)
    if not os.path.exists(path) or os.path.getsize(path) == 0:
        with open(path, "w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(header)

def append_row(path, row):
    """Doda eno vrstico v CSV (append & close)."""
    with open(path, "a", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(row)

# -------------------------------------------------------
# Kneserjev graf K(n,k): vozlišča so k‑podmnožice {1,...,n}, povezava če sta disjunktni.
# -------------------------------------------------------
def kneser_graph(n, k):
    """
    Vrne Sage graf K(n,k) in seznam vozlišč (kot tuple).
    """
    from sage.graphs.graph import Graph

    n = int(n); k = int(k)
    V = [tuple(c) for c in combinations(range(1, n + 1), k)]
    G = Graph(multiedges=False, loops=False)
    G.add_vertices(V)

    # povezave: disjunktnost
    for i in range(len(V)):
        A = set(V[i])
        for j in range(i + 1, len(V)):
            B = set(V[j])
            if A.isdisjoint(B):
                G.add_edge(V[i], V[j])

    return G, V

# -------------------------------------------------------
# Kvadrat grafa G^2: u--v v H, če (u--v v G) ali (N(u) ∩ N(v) ≠ ∅)
# + short-circuit: če n ≥ 3k-1, je G^2 poln ⇒ α(G^2)=1
# -------------------------------------------------------
def alpha_square_kneser(n, k, G):
    """
    Vrne α(G^2) za K(n,k). Če n >= 3k-1, je kvadrat poln ⇒ α(G^2)=1.
    Sicer konstruira kvadrat grafa in vrne independence_number.
    """
    n = int(n); k = int(k)
    if n >= 3*k - 1:
        return 1

    # sicer: zgradi kvadrat grafa
    from sage.graphs.graph import Graph
    H = Graph(multiedges=False, loops=False)
    H.add_vertices(G.vertices())

    N = {u: set(G.neighbors(u)) for u in G.vertices()}
    V = G.vertices()
    for i in range(len(V)):
        u = V[i]
        Nu = N[u]
        for j in range(i + 1, len(V)):
            v = V[j]
            if G.has_edge(u, v) or (len(Nu.intersection(N[v])) > 0):
                H.add_edge(u, v)

    try:
        return int(H.independence_number())
    except Exception:
        # fallback MIP (redko potreben)
        return independence_number_mip(H)

# -------------------------------------------------------
# α(G): običajno neodvisno število
# -------------------------------------------------------
def alpha_independence_number(G):
    try:
        return int(G.independence_number())
    except Exception:
        return independence_number_mip(G)

def independence_number_mip(G):
    p = MixedIntegerLinearProgram(maximization=True)
    x = p.new_variable(binary=True)
    p.set_objective(sum(x[u] for u in G.vertices()))
    for (u, v, _) in G.edges():
        p.add_constraint(x[u] + x[v] <= 1)
    p.solve()
    sol = p.get_values(x)
    return int(round(sum(sol[u] for u in G.vertices())))

# -------------------------------------------------------
# α_odd(G): ILP po vaši formulaciji (CLP)
# max sum_u x_u
# s.t. x_u ∈ {0,1}, y_u ∈ {0,1}, z_u ∈ Z_{>=0}
#      x_u + x_v ≤ 1, ∀uv ∈ E
#      sum_{v∈N(u)} x_v ≤ deg(u) * y_u, ∀u
#      y_u + sum_{v∈N(u)} x_v = 2 z_u, ∀u
# -------------------------------------------------------
def alpha_odd_ilp(G, timelimit_seconds=None, solver=None):
    """
    Vrne α_odd(G) po ILP formulaciji iz navodil.
    """
    p = MixedIntegerLinearProgram(maximization=True, solver=solver)
    x = p.new_variable(binary=True)  # xu ∈ {0,1}
    y = p.new_variable(binary=True)  # yu ∈ {0,1}
    z = p.new_variable(integer=True) # zu ≥ 0

    V = G.vertices()
    N = {u: list(G.neighbors(u)) for u in V}
    
    # cilj: maks. velikost lihe neodvisne množice
    p.set_objective(sum(x[u] for u in V))

    # 1) neodvisna množica: x_u + x_v ≤ 1 ∀ uv ∈ E
    for u, v, _ in G.edges():
        p.add_constraint(x[u] + x[v] <= 1)

    # 2) liha neodvisnost
    for u in V:
        # zu ≥ 0 implicitno
        # če nima sosedov, potem y_u = 0, sum x_v = 0 → 2 z_u = 0
        if len(N[u]) == 0:
            p.add_constraint(y[u] == 0)
            p.add_constraint(0 == 2 * z[u])
        else:
            # xv ≤ n * yu   za vse sosednje uv ∈ E
            for v in N[u]:
                p.add_constraint(x[v] <= len(N[u]) * y[u])
            # yu + sum_{v∈N(u)} x_v = 2 zu
            p.add_constraint(y[u] + sum(x[v] for v in N[u]) - 2 * z[u] == 0)

    # časovna meja solverja
    if timelimit_seconds is not None:
        try:
            p.solver_parameter("timelimit", float(timelimit_seconds))
        except Exception:
            pass

    # reši ILP
    try:
        p.solve()
    except MIPSolverException as e:
        print(f"⚠️ ILP solver ni našel rešitve: {e}")
        return None

    sol_x = p.get_values(x)
    alpha_odd = int(round(sum(sol_x[u] for u in V)))
    return alpha_odd

# -------------------------------------------------------
# α-parametri za Kneserjev graf K(n,k)
# -------------------------------------------------------
def alpha_params_for_kneser(n, k, ilp_timelimit=None, solver=None):
    """
    Vrne (G, α(G), α_odd(G), α(G^2)) za K(n,k).
    α(G): EKR za n >= 2k; sicer vgrajena funkcija.
    α_odd(G): ILP po dani formulaciji.
    α(G^2): neodvisno število kvadrata grafa (s short-circuit za n >= 3k-1).
    """
    n = int(n); k = int(k)
    G, V = kneser_graph(n, k)

    # α(G): EKR za n ≥ 2k
    if n >= 2 * k:
        alpha = math.comb(n - 1, k - 1)
    else:
        alpha = alpha_independence_number(G)

    # α_odd(G): po ILP
    alpha_od = alpha_odd_ilp(G, timelimit_seconds=ilp_timelimit, solver=solver)

    # α(G^2): s short-circuit za poln kvadrat
    alpha_sq = alpha_square_kneser(n, k, G)

    return G, alpha, alpha_od, alpha_sq

# ---------- Glavna rutina skeniranja ----------
def scan_kneser_family(
    n_min=1, n_max=11,          # po zahtevi
    MAX_V_FOR_CSV=600,          # informativno; zapis ne preskakujemo
    MAX_V_FOR_PLOT=100,
    plot_layout='circular',
    PRINT_PROGRESS=True,
    time_limit_seconds=None,    # pusti None, da zajame KG(11,5)
    max_cases=None,             # npr. 30 (ali None)
    ilp_timelimit=None,         # časovna meja ILP (npr. 60)
    solver=None                 # 'CBC', 'GLPK', ali None
):
    start_time = time.time()
    cases_done = 0

    csv_abs = os.path.abspath(CSV_PATH)
    print(f"📄 CSV bo shranjen v: {csv_abs}")
    print(f"📂 cwd: {os.getcwd()}")
    print(f"🗂️ Rezultati v: {os.path.abspath(BASE_DIR)}")

    ensure_csv_with_header(CSV_PATH)

    # poskrbi, da mapi za slike obstajata
    os.makedirs(DIR_EQ1, exist_ok=True)
    os.makedirs(DIR_EQ2, exist_ok=True)

    for n in range(int(n_min), int(n_max) + 1):
        for k in range(1, int(n) // 2 + 1):

            # kontrola časa/števil primerov
            if time_limit_seconds is not None and (time.time() - start_time) > float(time_limit_seconds):
                print(f"⏹️ Ustavljeno zaradi time_limit ({time_limit_seconds}s). Do sem: {cases_done} primerov.")
                return
            if max_cases is not None and cases_done >= int(max_cases):
                print(f"⏹️ Ustavljeno zaradi max_cases={max_cases}.")
                return

            V_count = math.comb(int(n), int(k))

            # informativno sporočilo (zapis v CSV ne preskakujemo)
            if V_count > int(MAX_V_FOR_CSV) and PRINT_PROGRESS:
                print(f"ℹ️ KG({n},{k}) |V|={V_count} > MAX_V_FOR_CSV={MAX_V_FOR_CSV}, zapis v CSV bo vseeno.")

            t0 = time.time()
            G, alpha, alpha_od, alpha_sq = alpha_params_for_kneser(n, k, ilp_timelimit=ilp_timelimit, solver=solver)
            eq1 = (alpha_od == alpha)     # α_odd = α
            eq2 = (alpha_od == alpha_sq)  # α_odd = α(G^2)
            seconds = round(time.time() - t0, 3)

            # zapis v CSV: vedno, za vse grafe
            append_row(CSV_PATH, [
                RUN_TAG, n, k, V_count, alpha, alpha_od, alpha_sq, bool(eq1), bool(eq2), seconds
            ])
            cases_done += 1

            if PRINT_PROGRESS:
                print(f"✅ KG({n},{k}) |V|={V_count}: α={alpha}, α_odd={alpha_od}, α(G^2)={alpha_sq} "
                      f"| eq1(α_odd=α)={eq1}, eq2(α_odd=α(G^2))={eq2} | {seconds}s")

            # ---------- izris ----------
            base = f"KG_{n}_{k}_V{V_count}_a{alpha}_aodd{alpha_od}_asq{alpha_sq}_{RUN_TAG}.png"

            # sliko za eq1 vedno naredimo
            if eq1:
                p1 = os.path.join(DIR_EQ1, base)
                try:
                    G.plot(layout=plot_layout).save(p1)
                except Exception as e:
                    print(f"⚠️ Napaka pri shranjevanju slike (eq1) za KG({n},{k}): {e}")
            elif V_count <= int(MAX_V_FOR_PLOT):
                p1 = os.path.join(DIR_EQ1, base)
                try:
                    G.plot(layout=plot_layout).save(p1)
                except Exception as e:
                    print(f"⚠️ Napaka pri shranjevanju slike (eq1*) za KG({n},{k}): {e}")

            # sliko za eq2 vedno naredimo
            if eq2:
                p2 = os.path.join(DIR_EQ2, base)
                try:
                    G.plot(layout=plot_layout).save(p2)
                except Exception as e:
                    print(f"⚠️ Napaka pri shranjevanju slike (eq2) za KG({n},{k}): {e}")
            elif V_count <= int(MAX_V_FOR_PLOT):
                p2 = os.path.join(DIR_EQ2, base)
                try:
                    G.plot(layout=plot_layout).save(p2)
                except Exception as e:
                    print(f"⚠️ Napaka pri shranjevanju slike (eq2*) za KG({n},{k}): {e}")

    # po koncu
    if os.path.exists(csv_abs):
        size = os.path.getsize(csv_abs)
        print(f"📏 CSV velikost: {size} bytes | zapisane vrstice: {cases_done}")
    print("⏱️ Skupen čas:", round(time.time() - start_time, 3), "s")

# ---------- Montaža (mozaik) ----------
def create_montage_from_dir(
    dir_path,
    output_path,
    thumb_size=(300, 300),
    cols=4,
    pad=10,
    add_labels=True,
    max_images=None
):
    try:
        from PIL import Image, ImageDraw, ImageFont
    except ImportError:
        print("⚠️ PIL (Pillow) ni nameščen v Sage okolju. Montaža se preskoči.")
        return

    if not os.path.isdir(dir_path):
        print(f"⚠️ Mapa za montažo ne obstaja: {dir_path}")
        return

    files = sorted([f for f in os.listdir(dir_path) if f.lower().endswith('.png')])
    if max_images is not None:
        files = files[:int(max_images)]
    if not files:
        print(f"⚠️ Ni slik v: {dir_path}, preskočim montažo.")
        return

    W, H = thumb_size
    rows = (len(files) + cols - 1) // cols
    canvas_w = cols * W + (cols + 1) * pad
    canvas_h = rows * H + (rows + 1) * pad

    from PIL import Image, ImageDraw, ImageFont
    canvas = Image.new('RGB', (canvas_w, canvas_h), color=(255, 255, 255))
    draw = ImageDraw.Draw(canvas)
    try:
        font = ImageFont.load_default()
    except Exception:
        font = None

    def parse_label_from_filename(fn):
        base = os.path.splitext(fn)[0]
        parts = base.split('_')
        vals = {"n": None, "k": None, "V": None, "a": None, "aodd": None, "asq": None}

        # prvi dve čisti številki kot n, k
        numeric = [p for p in parts if p.isdigit()]
        if len(numeric) >= 1:
            vals["n"] = numeric[0]
        if len(numeric) >= 2:
            vals["k"] = numeric[1]

        # prefiksi
        for p in parts:
            if p.startswith("V"):
                vals["V"] = p[1:]
            elif p.startswith("aodd"):
                vals["aodd"] = p[4:]
            elif p.startswith("asq"):
                vals["asq"] = p[3:]
            elif p.startswith("a") and not p.startswith("aodd") and not p.startswith("asq"):
                vals["a"] = p[1:]

        n = vals["n"] if vals["n"] is not None else "?"
        k = vals["k"] if vals["k"] is not None else "?"
        V = vals["V"] if vals["V"] is not None else "?"
        a = vals["a"] if vals["a"] is not None else "?"
        aod = vals["aodd"] if vals["aodd"] is not None else "?"
        asq = vals["asq"] if vals["asq"] is not None else "?"
        return f"n={n}, k={k}, V={V}\nα={a}, α_odd={aod}, α(G²)={asq}"

    for idx, fn in enumerate(files):
        full = os.path.join(dir_path, fn)
        try:
            img = Image.open(full).convert('RGB')
        except Exception as e:
            print(f"⚠️ Ne morem odpreti slike '{full}': {e}")
            continue

        img = img.resize(thumb_size, Image.LANCZOS)
        r = idx // cols
        c = idx % cols
        x = pad + c * (W + pad)
        y = pad + r * (H + pad)
        canvas.paste(img, (x, y))
        if add_labels and font is not None:
            try:
                draw.text((x + 5, y + 5), parse_label_from_filename(fn), fill=(0,0,0), font=font)
            except Exception:
                # če etiketa pade, sliko vseeno ohranimo
                pass

    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    canvas.save(output_path)
    print(f"🖼️ Montaža shranjena: {os.path.abspath(output_path)}")

# ---------- Zagon ----------
if __name__ == "__main__":
    # Parametriziran zagon
    scan_kneser_family(
        n_min=1, n_max=11,
        MAX_V_FOR_CSV=600,          # informativno
        MAX_V_FOR_PLOT=100,
        plot_layout='circular',
        PRINT_PROGRESS=True,
        time_limit_seconds=None,    # pusti None, da zajame KG(11,5)
        max_cases=None,
        ilp_timelimit=60,           # časovna meja za ILP (po potrebi zvišaj)
        solver=None                 # lahko 'CBC' ali 'GLPK' če želiš
    )

    # Obe montaži
    create_montage_from_dir(
        dir_path=DIR_EQ1,
        output_path=MONTAGE_EQ1,
        thumb_size=(320, 320),
        cols=4,
        pad=12,
        add_labels=True
    )

    create_montage_from_dir(
        dir_path=DIR_EQ2,
        output_path=MONTAGE_EQ2,
        thumb_size=(320, 320),
        cols=4,
        pad=12,
        add_labels=True
    )

    # Hitra kontrola CSV
    print("CSV pot:", os.path.abspath(CSV_PATH))
    print("CSV obstaja?", os.path.exists(CSV_PATH))
    print("CSV velikost (bytes):", os.path.getsize(CSV_PATH) if os.path.exists(CSV_PATH) else "NA")
# Out:
# 📄 CSV bo shranjen v: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints/results3/kneser_scan_run_20251208-153350.csv
# 📂 cwd: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints
# 🗂️ Rezultati v: /home/naana/projektna-naloga-fp/Ana_proba/.ipynb_checkpoints/results3
# ✅ KG(2,1) |V|=2: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.001s
# ✅ KG(3,1) |V|=3: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.001s
# ✅ KG(4,1) |V|=4: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.002s
# ✅ KG(4,2) |V|=6: α=3, α_odd=3, α(G^2)=3 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.001s
# ✅ KG(5,1) |V|=5: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.002s
# ✅ KG(5,2) |V|=10: α=4, α_odd=3, α(G^2)=1 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 0.003s
# ✅ KG(6,1) |V|=6: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.003s
# ✅ KG(6,2) |V|=15: α=5, α_odd=5, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.006s
# ✅ KG(6,3) |V|=20: α=10, α_odd=10, α(G^2)=10 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.002s
# ✅ KG(7,1) |V|=7: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.003s
# ✅ KG(7,2) |V|=21: α=6, α_odd=3, α(G^2)=1 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 0.039s
# ✅ KG(7,3) |V|=35: α=15, α_odd=15, α(G^2)=7 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.044s
# ✅ KG(8,1) |V|=8: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.005s
# ✅ KG(8,2) |V|=28: α=7, α_odd=7, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=False | 0.043s
# ✅ KG(8,3) |V|=56: α=21, α_odd=16, α(G^2)=1 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 2.622s
# ✅ KG(8,4) |V|=70: α=35, α_odd=35, α(G^2)=35 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.012s
# ✅ KG(9,1) |V|=9: α=1, α_odd=1, α(G^2)=1 | eq1(α_odd=α)=True, eq2(α_odd=α(G^2))=True | 0.008s
# ✅ KG(9,2) |V|=36: α=8, α_odd=3, α(G^2)=1 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 0.67s
# ⚠️ ILP solver ni našel rešitve: GLPK: The time limit has been exceeded
# ✅ KG(9,3) |V|=84: α=28, α_odd=None, α(G^2)=1 | eq1(α_odd=α)=False, eq2(α_odd=α(G^2))=False | 60.126s
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 108, in alpha_square_kneser(n, k, G)
#     107 try:
# --> 108     return int(H.independence_number())
#     109 except Exception:
#     110     # fallback MIP (redko potreben)
#
# AttributeError: 'Graph' object has no attribute 'independence_number'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 413
#     410 # ---------- Zagon ----------
#     411 if __name__ == "__main__":
#     412     # Parametriziran zagon
# --> 413     scan_kneser_family(
#     414         n_min=Integer(1), n_max=Integer(11),
#     415         MAX_V_FOR_CSV=Integer(600),          # informativno
#     416         MAX_V_FOR_PLOT=Integer(100),
#     417         plot_layout='circular',
#     418         PRINT_PROGRESS=True,
#     419         time_limit_seconds=None,    # pusti None, da zajame KG(11,5)
#     420         max_cases=None,
#     421         ilp_timelimit=Integer(60),           # časovna meja za ILP (po potrebi zvišaj)
#     422         solver=None                 # lahko 'CBC' ali 'GLPK' če želiš
#     423     )
#     425     # Obe montaži
#     426     create_montage_from_dir(
#     427         dir_path=DIR_EQ1,
#     428         output_path=MONTAGE_EQ1,
#    (...)
#     432         add_labels=True
#     433     )
#
# Cell In[19], line 262, in scan_kneser_family(n_min, n_max, MAX_V_FOR_CSV, MAX_V_FOR_PLOT, plot_layout, PRINT_PROGRESS, time_limit_seconds, max_cases, ilp_timelimit, solver)
#     259     print(f"ℹ️ KG({n},{k}) |V|={V_count} > MAX_V_FOR_CSV={MAX_V_FOR_CSV}, zapis v CSV bo vseeno.")
#     261 t0 = time.time()
# --> 262 G, alpha, alpha_od, alpha_sq = alpha_params_for_kneser(n, k, ilp_timelimit=ilp_timelimit, solver=solver)
#     263 eq1 = (alpha_od == alpha)     # α_odd = α
#     264 eq2 = (alpha_od == alpha_sq)  # α_odd = α(G^2)
#
# Cell In[19], line 214, in alpha_params_for_kneser(n, k, ilp_timelimit, solver)
#     211 alpha_od = alpha_odd_ilp(G, timelimit_seconds=ilp_timelimit, solver=solver)
#     213 # α(G^2): s short-circuit za poln kvadrat
# --> 214 alpha_sq = alpha_square_kneser(n, k, G)
#     216 return G, alpha, alpha_od, alpha_sq
#
# Cell In[19], line 111, in alpha_square_kneser(n, k, G)
#     108     return int(H.independence_number())
#     109 except Exception:
#     110     # fallback MIP (redko potreben)
# --> 111     return independence_number_mip(H)
#
# Cell In[19], line 128, in independence_number_mip(G)
#     126 for (u, v, _) in G.edges():
#     127     p.add_constraint(x[u] + x[v] <= Integer(1))
# --> 128 p.solve()
#     129 sol = p.get_values(x)
#     130 return int(round(sum(sol[u] for u in G.vertices())))
#
# File ~/miniconda3/envs/sagemath/lib/python3.12/site-packages/sage/numerical/mip.pyx:2641, in sage.numerical.mip.MixedIntegerLinearProgram.solve (build/cythonized/sage/numerical/mip.c:22310)()
#    2639 if log is not None:
#    2640     self._backend.set_verbosity(log)
# -> 2641 self._backend.solve()
#    2642 return self._backend.get_objective_value()
#    2643
#
# File ~/miniconda3/envs/sagemath/lib/python3.12/site-packages/sage/numerical/backends/glpk_backend.pyx:1130, in sage.numerical.backends.glpk_backend.GLPKBackend.solve (build/cythonized/sage/numerical/backends/glpk_backend.c:16096)()
#    1128 if ((self.simplex_or_intopt == glp_intopt_only)
#    1129     or (self.simplex_or_intopt == glp_simplex_then_intopt) and (solution_status != GLP_UNDEF) and (solution_status != GLP_NOFEAS)):
# -> 1130     sig_on()
#    1131     solve_status = glp_intopt(self.lp, self.iocp)
#    1132     solution_status = glp_mip_status(self.lp)
#
# KeyboardInterrupt:
